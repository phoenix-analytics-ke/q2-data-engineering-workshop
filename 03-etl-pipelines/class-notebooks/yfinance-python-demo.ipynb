# %% [markdown]
# ## Install yfinance

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (0.2.41)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (2.0.1)
# Requirement already satisfied: requests>=2.31 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (5.2.2)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tevin_solutech\desktop\tems\bootcamp\q2-data-engineering-workshop\venv\lib\site-packages (from requests>=2.31->yfinance) (2024.7.4)
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Import yfinance and Pandas

# %%
import pandas as pd
import yfinance as yf

# %%
dir(yf)
# Out:
# ['Ticker',
#  'Tickers',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'base',
#  'cache',
#  'const',
#  'data',
#  'download',
#  'enable_debug_mode',
#  'exceptions',
#  'multi',
#  'scrapers',
#  'set_tz_cache_location',
#  'shared',
#  'ticker',
#  'tickers',
#  'utils',
#  'version',
#  'warnings']

# %% [markdown]
# ## How to Download Historical Price Data Using yfinance

# %% [markdown]
# We can download data for one ticker using the Ticker object and multiple tickers using the download method.

# %% [markdown]
# ### Download One Ticker Using yfinance

# %% [markdown]
# First, we need to create a ticker object and then use that object to get our data. Creating a ticker object is straightforward:

# %%
obj = yf.Ticker('goog')
obj
# Out:
# yfinance.Ticker object <GOOG>

# %%
dir(obj)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analysis',
#  '_data',
#  '_download_options',
#  '_earnings',
#  '_earnings_dates',
#  '_expirations',
#  '_fast_info',
#  '_fetch_ticker_tz',
#  '_financials',
#  '_fundamentals',
#  '_get_ticker_tz',
#  '_holders',
#  '_isin',
#  '_lazy_load_price_history',
#  '_news',
#  '_options2df',
#  '_price_history',
#  '_quote',
#  '_shares',
#  '_tz',
#  '_underlying',
#  'actions',
#  'analyst_price_target',
#  'balance_sheet',
#  'balancesheet',
#  'basic_info',
#  'calendar',
#  'capital_gains',
#  'cash_flow',
#  'cashflow',
#  'dividends',
#  'earnings',
#  'earnings_dates',
#  'earnings_forecasts',
#  'earnings_trend',
#  'fast_info',
#  'financials',
#  'get_actions',
#  'get_analyst_price_target',
#  'get_balance_sheet',
#  'get_balancesheet',
#  'get_calendar',
#  'get_capital_gains',
#  'get_cash_flow',
#  'get_cashflow',
#  'get_dividends',
#  'get_earnings',
#  'get_earnings_dates',
#  'get_earnings_forecast',
#  'get_earnings_trend',
#  'get_fast_info',
#  'get_financials',
#  'get_history_metadata',
#  'get_income_stmt',
#  'get_incomestmt',
#  'get_info',
#  'get_insider_purchases',
#  'get_insider_roster_holders',
#  'get_insider_transactions',
#  'get_institutional_holders',
#  'get_isin',
#  'get_major_holders',
#  'get_mutualfund_holders',
#  'get_news',
#  'get_recommendations',
#  'get_recommendations_summary',
#  'get_rev_forecast',
#  'get_shares',
#  'get_shares_full',
#  'get_splits',
#  'get_sustainability',
#  'get_trend_details',
#  'get_upgrades_downgrades',
#  'history',
#  'history_metadata',
#  'income_stmt',
#  'incomestmt',
#  'info',
#  'insider_purchases',
#  'insider_roster_holders',
#  'insider_transactions',
#  'institutional_holders',
#  'isin',
#  'major_holders',
#  'mutualfund_holders',
#  'news',
#  'option_chain',
#  'options',
#  'proxy',
#  'quarterly_balance_sheet',
#  'quarterly_balancesheet',
#  'quarterly_cash_flow',
#  'quarterly_cashflow',
#  'quarterly_earnings',
#  'quarterly_financials',
#  'quarterly_income_stmt',
#  'quarterly_incomestmt',
#  'recommendations',
#  'recommendations_summary',
#  'revenue_forecasts',
#  'session',
#  'shares',
#  'splits',
#  'sustainability',
#  'ticker',
#  'trend_details',
#  'upgrades_downgrades']

# %%
goog = yf.Ticker('goog')
data = goog.history()
data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-07-09 00:00:00-04:00  191.750000  192.860001  190.229996  190.440002
# 2024-07-10 00:00:00-04:00  190.750000  193.309998  190.619995  192.660004
# 2024-07-11 00:00:00-04:00  191.339996  192.410004  186.820007  187.300003
# 2024-07-12 00:00:00-04:00  186.919998  188.690002  186.139999  186.779999
# 2024-07-15 00:00:00-04:00  186.490005  189.899994  186.490005  188.190002
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-07-09 00:00:00-04:00  10198500        0.0           0.0
# 2024-07-10 00:00:00-04:00  12052900        0.0           0.0
# 2024-07-11 00:00:00-04:00  16452000        0.0           0.0
# 2024-07-12 00:00:00-04:00  14449100        0.0           0.0
# 2024-07-15 00:00:00-04:00  12186000        0.0           0.0

# %%
data = goog.history(interval='1m', start='2022-01-03', end='2022-01-10')
data.head()
# Out:
# GOOG: 1m data not available for startTime=1641186000 and endTime=1641790800. The requested range must be within the last 30 days.
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# ### Download Multiple Tickers Using yfinance

# %%
data = yf.download(['GOOG','META'], period='1mo')
data.head()
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Price        Adj Close                   Close                    High  \
# Ticker            GOOG        META        GOOG        META        GOOG
# Date
# 2024-07-09  190.440002  530.000000  190.440002  530.000000  192.860001
# 2024-07-10  192.660004  534.690002  192.660004  534.690002  193.309998
# 2024-07-11  187.300003  512.700012  187.300003  512.700012  192.410004
# 2024-07-12  186.779999  498.869995  186.779999  498.869995  188.690002
# 2024-07-15  188.190002  496.160004  188.190002  496.160004  189.899994
#
# Price                          Low                    Open              \
# Ticker            META        GOOG        META        GOOG        META
# Date
# 2024-07-09  537.479980  190.229996  528.190002  191.750000  533.750000
# 2024-07-10  538.880005  190.619995  528.359985  190.750000  530.789978
# 2024-07-11  535.460022  186.820007  508.369995  191.339996  530.890015
# 2024-07-12  508.089996  186.139999  494.230011  186.919998  497.760010
# 2024-07-15  506.679993  186.490005  493.369995  186.490005  498.630005
#
# Price         Volume
# Ticker          GOOG      META
# Date
# 2024-07-09  10198500   8753200
# 2024-07-10  12052900  10983300
# 2024-07-11  16452000  16458300
# 2024-07-12  14449100  19750500
# 2024-07-15  12186000  12539200

# %%
data = yf.download(['GOOG','META'], start='2021-12-10', end='2021-12-30', group_by='ticker')
data.head()
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Ticker            META                                                  \
# Price             Open        High         Low       Close   Adj Close
# Date
# 2021-12-10  332.559998  335.029999  326.369995  329.750000  329.073792
# 2021-12-13  330.950012  341.089996  329.589996  334.489990  333.804047
# 2021-12-14  328.049988  335.700012  327.649994  333.739990  333.055573
# 2021-12-15  332.489990  342.109985  323.980011  341.660004  340.959351
# 2021-12-16  338.980011  344.459991  333.739990  334.899994  334.213226
#
# Ticker                      GOOG                                      \
# Price         Volume        Open        High         Low       Close
# Date
# 2021-12-10  14528000  149.100006  149.399994  147.357498  148.675003
# 2021-12-13  22948700  148.444000  148.562500  146.360001  146.704498
# 2021-12-14  20461000  144.770004  145.442001  142.242493  144.970505
# 2021-12-15  24681300  144.365997  147.517242  142.705505  147.368500
# 2021-12-16  22635000  148.076996  148.551498  144.092499  144.838501
#
# Ticker
# Price        Adj Close    Volume
# Date
# 2021-12-10  148.506012  21634000
# 2021-12-13  146.537750  24104000
# 2021-12-14  144.805725  24778000
# 2021-12-15  147.200989  27280000
# 2021-12-16  144.673874  27400000

# %% [markdown]
# ## How to Download Fundamental Data Using yfinance

# %% [markdown]
# We can loop through multiple tickers objects to download fundamental data for various tickers.

# %%
dhr = yf.Ticker('DHR')
info = dhr.info
info.keys()
# Out:
# dict_keys(['address1', 'address2', 'city', 'state', 'zip', 'country', 'phone', 'fax', 'website', 'industry', 'industryKey', 'industryDisp', 'sector', 'sectorKey', 'sectorDisp', 'longBusinessSummary', 'fullTimeEmployees', 'companyOfficers', 'auditRisk', 'boardRisk', 'compensationRisk', 'shareHolderRightsRisk', 'overallRisk', 'governanceEpochDate', 'compensationAsOfEpochDate', 'irWebsite', 'maxAge', 'priceHint', 'previousClose', 'open', 'dayLow', 'dayHigh', 'regularMarketPreviousClose', 'regularMarketOpen', 'regularMarketDayLow', 'regularMarketDayHigh', 'dividendRate', 'dividendYield', 'exDividendDate', 'payoutRatio', 'fiveYearAvgDividendYield', 'beta', 'trailingPE', 'forwardPE', 'volume', 'regularMarketVolume', 'averageVolume', 'averageVolume10days', 'averageDailyVolume10Day', 'bidSize', 'askSize', 'marketCap', 'fiftyTwoWeekLow', 'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months', 'fiftyDayAverage', 'twoHundredDayAverage', 'trailingAnnualDividendRate', 'trailingAnnualDividendYield', 'currency', 'enterpriseValue', 'profitMargins', 'floatShares', 'sharesOutstanding', 'sharesShort', 'sharesShortPriorMonth', 'sharesShortPreviousMonthDate', 'dateShortInterest', 'sharesPercentSharesOut', 'heldPercentInsiders', 'heldPercentInstitutions', 'shortRatio', 'shortPercentOfFloat', 'impliedSharesOutstanding', 'bookValue', 'priceToBook', 'lastFiscalYearEnd', 'nextFiscalYearEnd', 'mostRecentQuarter', 'earningsQuarterlyGrowth', 'netIncomeToCommon', 'trailingEps', 'forwardEps', 'pegRatio', 'lastSplitFactor', 'lastSplitDate', 'enterpriseToRevenue', 'enterpriseToEbitda', '52WeekChange', 'SandP52WeekChange', 'lastDividendValue', 'lastDividendDate', 'exchange', 'quoteType', 'symbol', 'underlyingSymbol', 'shortName', 'longName', 'firstTradeDateEpochUtc', 'timeZoneFullName', 'timeZoneShortName', 'uuid', 'messageBoardId', 'gmtOffSetMilliseconds', 'currentPrice', 'targetHighPrice', 'targetLowPrice', 'targetMeanPrice', 'targetMedianPrice', 'recommendationMean', 'recommendationKey', 'numberOfAnalystOpinions', 'totalCash', 'totalCashPerShare', 'ebitda', 'totalDebt', 'quickRatio', 'currentRatio', 'totalRevenue', 'debtToEquity', 'revenuePerShare', 'returnOnAssets', 'returnOnEquity', 'freeCashflow', 'operatingCashflow', 'earningsGrowth', 'revenueGrowth', 'grossMargins', 'ebitdaMargins', 'operatingMargins', 'financialCurrency', 'trailingPegRatio'])

# %%
info['sector']
# Out:
# 'Healthcare'

# %%
dhr.earnings
# Out:
# c:\Users\tevin_solutech\Desktop\Tems\Bootcamp\q2-data-engineering-workshop\venv\Lib\site-packages\yfinance\scrapers\fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)

# %%
dhr.get_financials()
# Out:
#                                                        2023-12-31  \
# TaxEffectOfUnusualItems                               -42217000.0
# TaxRateForCalcs                                             0.163
# NormalizedEBITDA                                     7755000000.0
# TotalUnusualItems                                    -259000000.0
# TotalUnusualItemsExcludingGoodwill                   -259000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   4221000000.0
# ReconciledDepreciation                               2166000000.0
# ReconciledCostOfRevenue                              9856000000.0
# EBITDA                                               7496000000.0
# EBIT                                                 5330000000.0
# NetInterestIncome                                      17000000.0
# InterestExpense                                       286000000.0
# InterestIncome                                        303000000.0
# NormalizedIncome                                     4437783000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      4764000000.0
# TotalExpenses                                       18611000000.0
# TotalOperatingIncomeAsReported                       5202000000.0
# DilutedAverageShares                                  743100000.0
# BasicAverageShares                                    736500000.0
# DilutedEPS                                                   6.38
# BasicEPS                                                     6.44
# DilutedNIAvailtoComStockholders                      4743000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          4743000000.0
# PreferredStockDividends                                21000000.0
# NetIncome                                            4764000000.0
# NetIncomeIncludingNoncontrollingInterests            4764000000.0
# NetIncomeDiscontinuousOperations                      543000000.0
# NetIncomeContinuousOperations                        4221000000.0
# TaxProvision                                          823000000.0
# PretaxIncome                                         5044000000.0
# OtherIncomeExpense                                   -252000000.0
# OtherNonOperatingIncomeExpenses                         7000000.0
# SpecialIncomeCharges                                 -108000000.0
# GainOnSaleOfBusiness                                          0.0
# OtherSpecialCharges                                           NaN
# WriteOff                                              108000000.0
# GainOnSaleOfSecurity                                 -151000000.0
# NetNonOperatingInterestIncomeExpense                   17000000.0
# InterestExpenseNonOperating                           286000000.0
# InterestIncomeNonOperating                            303000000.0
# OperatingIncome                                      5279000000.0
# OperatingExpense                                     8755000000.0
# OtherOperatingExpenses                                        NaN
# ResearchAndDevelopment                               1503000000.0
# SellingGeneralAndAdministration                      7252000000.0
# GrossProfit                                         14034000000.0
# CostOfRevenue                                        9856000000.0
# TotalRevenue                                        23890000000.0
# OperatingRevenue                                    23890000000.0
#
#                                                        2022-12-31  \
# TaxEffectOfUnusualItems                               -30894000.0
# TaxRateForCalcs                                             0.114
# NormalizedEBITDA                                     9753000000.0
# TotalUnusualItems                                    -271000000.0
# TotalUnusualItemsExcludingGoodwill                   -271000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   6328000000.0
# ReconciledDepreciation                               2132000000.0
# ReconciledCostOfRevenue                             10455000000.0
# EBITDA                                               9482000000.0
# EBIT                                                 7350000000.0
# NetInterestIncome                                    -163000000.0
# InterestExpense                                       204000000.0
# InterestIncome                                         41000000.0
# NormalizedIncome                                     6568106000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      7209000000.0
# TotalExpenses                                       19107000000.0
# TotalOperatingIncomeAsReported                       7536000000.0
# DilutedAverageShares                                  737100000.0
# BasicAverageShares                                    725100000.0
# DilutedEPS                                                   9.66
# BasicEPS                                                      9.8
# DilutedNIAvailtoComStockholders                      7103000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          7103000000.0
# PreferredStockDividends                               106000000.0
# NetIncome                                            7209000000.0
# NetIncomeIncludingNoncontrollingInterests            7209000000.0
# NetIncomeDiscontinuousOperations                      881000000.0
# NetIncomeContinuousOperations                        6328000000.0
# TaxProvision                                          818000000.0
# PretaxIncome                                         7146000000.0
# OtherIncomeExpense                                   -227000000.0
# OtherNonOperatingIncomeExpenses                        44000000.0
# SpecialIncomeCharges                                  -91000000.0
# GainOnSaleOfBusiness                                          0.0
# OtherSpecialCharges                                           NaN
# WriteOff                                               91000000.0
# GainOnSaleOfSecurity                                 -180000000.0
# NetNonOperatingInterestIncomeExpense                 -163000000.0
# InterestExpenseNonOperating                           204000000.0
# InterestIncomeNonOperating                             41000000.0
# OperatingIncome                                      7536000000.0
# OperatingExpense                                     8652000000.0
# OtherOperatingExpenses                                        NaN
# ResearchAndDevelopment                               1528000000.0
# SellingGeneralAndAdministration                      7124000000.0
# GrossProfit                                         16188000000.0
# CostOfRevenue                                       10455000000.0
# TotalRevenue                                        26643000000.0
# OperatingRevenue                                    26643000000.0
#
#                                                        2021-12-31  \
# TaxEffectOfUnusualItems                                48900000.0
# TaxRateForCalcs                                             0.163
# NormalizedEBITDA                                     8504000000.0
# TotalUnusualItems                                     300000000.0
# TotalUnusualItemsExcludingGoodwill                    300000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   5447000000.0
# ReconciledDepreciation                               2062000000.0
# ReconciledCostOfRevenue                              9563000000.0
# EBITDA                                               8804000000.0
# EBIT                                                 6742000000.0
# NetInterestIncome                                    -220000000.0
# InterestExpense                                       231000000.0
# InterestIncome                                         11000000.0
# NormalizedIncome                                     5195900000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      6433000000.0
# TotalExpenses                                       18415000000.0
# TotalOperatingIncomeAsReported                       6377000000.0
# DilutedAverageShares                                  736800000.0
# BasicAverageShares                                    714600000.0
# DilutedEPS                                                   8.61
# BasicEPS                                                     8.77
# DilutedNIAvailtoComStockholders                      6269000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          6269000000.0
# PreferredStockDividends                               164000000.0
# NetIncome                                            6433000000.0
# NetIncomeIncludingNoncontrollingInterests            6433000000.0
# NetIncomeDiscontinuousOperations                      986000000.0
# NetIncomeContinuousOperations                        5447000000.0
# TaxProvision                                         1064000000.0
# PretaxIncome                                         6511000000.0
# OtherIncomeExpense                                    344000000.0
# OtherNonOperatingIncomeExpenses                        44000000.0
# SpecialIncomeCharges                                 -101000000.0
# GainOnSaleOfBusiness                                    5000000.0
# OtherSpecialCharges                                    96000000.0
# WriteOff                                               10000000.0
# GainOnSaleOfSecurity                                  401000000.0
# NetNonOperatingInterestIncomeExpense                 -220000000.0
# InterestExpenseNonOperating                           231000000.0
# InterestIncomeNonOperating                             11000000.0
# OperatingIncome                                      6387000000.0
# OperatingExpense                                     8852000000.0
# OtherOperatingExpenses                                547000000.0
# ResearchAndDevelopment                               1498000000.0
# SellingGeneralAndAdministration                      6807000000.0
# GrossProfit                                         15239000000.0
# CostOfRevenue                                        9563000000.0
# TotalRevenue                                        24802000000.0
# OperatingRevenue                                    24802000000.0
#
#                                                        2020-12-31 2019-12-31
# TaxEffectOfUnusualItems                                84483000.0        NaN
# TaxRateForCalcs                                             0.189        NaN
# NormalizedEBITDA                                     6098000000.0        NaN
# TotalUnusualItems                                     447000000.0        NaN
# TotalUnusualItemsExcludingGoodwill                    447000000.0        NaN
# NetIncomeFromContinuingOperationNetMinorityInte...   3646000000.0        NaN
# ReconciledDepreciation                               1775000000.0        NaN
# ReconciledCostOfRevenue                              9809000000.0        NaN
# EBITDA                                               6545000000.0        NaN
# EBIT                                                 4770000000.0        NaN
# NetInterestIncome                                    -204000000.0        NaN
# InterestExpense                                       275000000.0        NaN
# InterestIncome                                         71000000.0        NaN
# NormalizedIncome                                     3283483000.0        NaN
# NetIncomeFromContinuingAndDiscontinuedOperation      3646000000.0        NaN
# TotalExpenses                                       18053000000.0        NaN
# TotalOperatingIncomeAsReported                       4231000000.0        NaN
# DilutedAverageShares                                  718700000.0        NaN
# BasicAverageShares                                    706200000.0        NaN
# DilutedEPS                                                   4.89        NaN
# BasicEPS                                                     4.97        NaN
# DilutedNIAvailtoComStockholders                      3510000000.0        NaN
# AverageDilutionEarnings                                 1000000.0        NaN
# NetIncomeCommonStockholders                          3510000000.0        NaN
# PreferredStockDividends                               136000000.0        NaN
# NetIncome                                            3646000000.0        NaN
# NetIncomeIncludingNoncontrollingInterests            3646000000.0        NaN
# NetIncomeDiscontinuousOperations                              0.0        NaN
# NetIncomeContinuousOperations                        3646000000.0        NaN
# TaxProvision                                          849000000.0        NaN
# PretaxIncome                                         4495000000.0        NaN
# OtherIncomeExpense                                    468000000.0        NaN
# OtherNonOperatingIncomeExpenses                        21000000.0        NaN
# SpecialIncomeCharges                                  429000000.0        NaN
# GainOnSaleOfBusiness                                  455000000.0        NaN
# OtherSpecialCharges                                    26000000.0  7000000.0
# WriteOff                                                      NaN        NaN
# GainOnSaleOfSecurity                                   18000000.0        NaN
# NetNonOperatingInterestIncomeExpense                 -204000000.0        NaN
# InterestExpenseNonOperating                           275000000.0        NaN
# InterestIncomeNonOperating                             71000000.0        NaN
# OperatingIncome                                      4231000000.0        NaN
# OperatingExpense                                     8244000000.0        NaN
# OtherOperatingExpenses                                        NaN        NaN
# ResearchAndDevelopment                               1348000000.0        NaN
# SellingGeneralAndAdministration                      6896000000.0        NaN
# GrossProfit                                         12475000000.0        NaN
# CostOfRevenue                                        9809000000.0        NaN
# TotalRevenue                                        22284000000.0        NaN
# OperatingRevenue                                    22284000000.0        NaN

# %%
pnl = dhr.financials
bs = dhr.balancesheet
cf = dhr.cashflow
fs = pd.concat([pnl,bs,cf])
fs
# Out:
#                                           2023-12-31    2022-12-31  \
# Tax Effect Of Unusual Items              -42217000.0   -30894000.0
# Tax Rate For Calcs                             0.163         0.114
# Normalized EBITDA                       7755000000.0  9753000000.0
# Total Unusual Items                     -259000000.0  -271000000.0
# Total Unusual Items Excluding Goodwill  -259000000.0  -271000000.0
# ...                                              ...           ...
# Amortization Of Intangibles             1491000000.0  1434000000.0
# Depreciation                             675000000.0   698000000.0
# Operating Gains Losses                   182000000.0   271000000.0
# Gain Loss On Sale Of Business            182000000.0   271000000.0
# Net Income From Continuing Operations   4221000000.0  6328000000.0
#
#                                           2021-12-31    2020-12-31 2019-12-31
# Tax Effect Of Unusual Items               48900000.0    84483000.0        NaN
# Tax Rate For Calcs                             0.163         0.189        NaN
# Normalized EBITDA                       8504000000.0  6098000000.0        NaN
# Total Unusual Items                      300000000.0   447000000.0        NaN
# Total Unusual Items Excluding Goodwill   300000000.0   447000000.0        NaN
# ...                                              ...           ...        ...
# Amortization Of Intangibles             1388000000.0  1138000000.0        NaN
# Depreciation                             674000000.0   637000000.0        NaN
# Operating Gains Losses                  -310000000.0  -429000000.0        NaN
# Gain Loss On Sale Of Business           -406000000.0  -455000000.0        NaN
# Net Income From Continuing Operations   5447000000.0  3646000000.0        NaN
#
# [191 rows x 5 columns]

# %%
fs.T
# Out:
#            Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 2023-12-31                 -42217000.0              0.163      7755000000.0
# 2022-12-31                 -30894000.0              0.114      9753000000.0
# 2021-12-31                  48900000.0              0.163      8504000000.0
# 2020-12-31                  84483000.0              0.189      6098000000.0
# 2019-12-31                         NaN                NaN               NaN
#
#            Total Unusual Items Total Unusual Items Excluding Goodwill  \
# 2023-12-31        -259000000.0                           -259000000.0
# 2022-12-31        -271000000.0                           -271000000.0
# 2021-12-31         300000000.0                            300000000.0
# 2020-12-31         447000000.0                            447000000.0
# 2019-12-31                 NaN                                    NaN
#
#            Net Income From Continuing Operation Net Minority Interest  \
# 2023-12-31                                       4221000000.0
# 2022-12-31                                       6328000000.0
# 2021-12-31                                       5447000000.0
# 2020-12-31                                       3646000000.0
# 2019-12-31                                                NaN
#
#            Reconciled Depreciation Reconciled Cost Of Revenue        EBITDA  \
# 2023-12-31            2166000000.0               9856000000.0  7496000000.0
# 2022-12-31            2132000000.0              10455000000.0  9482000000.0
# 2021-12-31            2062000000.0               9563000000.0  8804000000.0
# 2020-12-31            1775000000.0               9809000000.0  6545000000.0
# 2019-12-31                     NaN                        NaN           NaN
#
#                     EBIT  ... Other Non Cash Items Stock Based Compensation  \
# 2023-12-31  5330000000.0  ...            8000000.0              306000000.0
# 2022-12-31  7350000000.0  ...                  NaN              295000000.0
# 2021-12-31  6742000000.0  ...          601000000.0              184000000.0
# 2020-12-31  4770000000.0  ...          457000000.0              187000000.0
# 2019-12-31           NaN  ...                  NaN                      NaN
#
#            Depreciation Amortization Depletion Depreciation And Amortization  \
# 2023-12-31                        2166000000.0                  2166000000.0
# 2022-12-31                        2132000000.0                  2132000000.0
# 2021-12-31                        2062000000.0                  2062000000.0
# 2020-12-31                        1775000000.0                  1775000000.0
# 2019-12-31                                 NaN                           NaN
#
#            Amortization Cash Flow Amortization Of Intangibles Depreciation  \
# 2023-12-31           1491000000.0                1491000000.0  675000000.0
# 2022-12-31           1434000000.0                1434000000.0  698000000.0
# 2021-12-31           1388000000.0                1388000000.0  674000000.0
# 2020-12-31           1138000000.0                1138000000.0  637000000.0
# 2019-12-31                    NaN                         NaN          NaN
#
#            Operating Gains Losses Gain Loss On Sale Of Business  \
# 2023-12-31            182000000.0                   182000000.0
# 2022-12-31            271000000.0                   271000000.0
# 2021-12-31           -310000000.0                  -406000000.0
# 2020-12-31           -429000000.0                  -455000000.0
# 2019-12-31                    NaN                           NaN
#
#            Net Income From Continuing Operations
# 2023-12-31                          4221000000.0
# 2022-12-31                          6328000000.0
# 2021-12-31                          5447000000.0
# 2020-12-31                          3646000000.0
# 2019-12-31                                   NaN
#
# [5 rows x 191 columns]

# %% [markdown]
# ### Download Fundamentals for Multiple Tickers Using yfinance

# %%
tickers = ['FB','AMZN','NFLX','GOOG']
tickers
# Out:
# ['FB', 'AMZN', 'NFLX', 'GOOG']

# %%
tickers = [yf.Ticker(ticker) for ticker in tickers]
tickers
# Out:
# [yfinance.Ticker object <FB>,
#  yfinance.Ticker object <AMZN>,
#  yfinance.Ticker object <NFLX>,
#  yfinance.Ticker object <GOOG>]

# %%
dfs = [] # list for each ticker's dataframe
for ticker in tickers:
    # get each financial statement
    pnl = ticker.financials
    bs = ticker.balancesheet
    cf = ticker.cashflow
    
    # concatenate into one dataframe
    fs = pd.concat([pnl, bs, cf])
    
    # make dataframe format nicer
    data = fs.T # Swap dates and columns
    data = data.reset_index() # reset index (date) into a column
    data.columns = ['Date', *data.columns[1:]] # Rename old index from '' to Date
    data['Ticker'] = ticker.ticker # Add ticker to dataframe
    dfs.append(data)
data
# Out:
#         Date Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 0 2023-12-31                -286479000.0              0.139    100032000000.0
# 1 2022-12-31                -981507000.0              0.159     91333000000.0
# 2 2021-12-31                1948860000.0              0.162     91491000000.0
# 3 2020-12-31            970572126.783412           0.162493     55941000000.0
# 4 2019-12-31                         NaN                NaN               NaN
#
#   Total Unusual Items Total Unusual Items Excluding Goodwill  \
# 0       -2061000000.0                          -2061000000.0
# 1       -6173000000.0                          -6173000000.0
# 2       12030000000.0                          12030000000.0
# 3        5973000000.0                           5973000000.0
# 4                 NaN                                    NaN
#
#   Net Income From Continuing Operation Net Minority Interest  \
# 0                                      73795000000.0
# 1                                      59972000000.0
# 2                                      76033000000.0
# 3                                      40269000000.0
# 4                                                NaN
#
#   Reconciled Depreciation Reconciled Cost Of Revenue          EBITDA  ...  \
# 0           11946000000.0             133332000000.0   97971000000.0  ...
# 1           13475000000.0             126203000000.0   85160000000.0  ...
# 2           12441000000.0             110939000000.0  103521000000.0  ...
# 3           13697000000.0              84732000000.0   61914000000.0  ...
# 4                     NaN                        NaN             NaN  ...
#
#   Deferred Income Tax Depreciation Amortization Depletion  \
# 0       -7763000000.0                       11946000000.0
# 1       -8081000000.0                       13475000000.0
# 2        1808000000.0                       12441000000.0
# 3        1390000000.0                       13697000000.0
# 4                 NaN                                 NaN
#
#   Depreciation And Amortization Amortization Cash Flow  \
# 0                 11946000000.0                    NaN
# 1                 13475000000.0            641000000.0
# 2                 12441000000.0            886000000.0
# 3                 13697000000.0            792000000.0
# 4                           NaN            925000000.0
#
#   Amortization Of Intangibles   Depreciation Operating Gains Losses  \
# 0                         NaN  11946000000.0            823000000.0
# 1                 641000000.0  13475000000.0           5519000000.0
# 2                 886000000.0  11555000000.0         -12270000000.0
# 3                 792000000.0  12905000000.0          -6317000000.0
# 4                 925000000.0            NaN                    NaN
#
#   Gain Loss On Investment Securities Net Income From Continuing Operations  \
# 0                        823000000.0                         73795000000.0
# 1                       5519000000.0                         59972000000.0
# 2                     -12270000000.0                         76033000000.0
# 3                      -6317000000.0                         40269000000.0
# 4                                NaN                                   NaN
#
#   Ticker
# 0   GOOG
# 1   GOOG
# 2   GOOG
# 3   GOOG
# 4   GOOG
#
# [5 rows x 179 columns]

# %%
data.iloc[:,:3]
# Out:
#         Date Tax Effect Of Unusual Items Tax Rate For Calcs
# 0 2023-12-31                -286479000.0              0.139
# 1 2022-12-31                -981507000.0              0.159
# 2 2021-12-31                1948860000.0              0.162
# 3 2020-12-31            970572126.783412           0.162493
# 4 2019-12-31                         NaN                NaN

# %%
parser = pd.io.parsers.base_parser.ParserBase({'usecols': None})

for df in dfs:
     df.columns = parser._maybe_dedup_names(df.columns)
df = pd.concat(dfs, ignore_index=True)
df = df.set_index(['Ticker','Date'])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 4
#       1 parser = pd.io.parsers.base_parser.ParserBase({'usecols': None})
#       3 for df in dfs:
# ----> 4      df.columns = parser._maybe_dedup_names(df.columns)
#       5 df = pd.concat(dfs, ignore_index=True)
#       6 df = df.set_index(['Ticker','Date'])
#
# AttributeError: 'ParserBase' object has no attribute '_maybe_dedup_names'

# %% [markdown]
# ## Hows to Get Options Data Using yfinance

# %% [markdown]
# Options give traders the right but not the obligation to buy or sell underlying assets at a specific price at a predetermined date. Options Trading has matured over the past century and has seen landmark events. Here is a chronicle of the history of options trading and the major events that have led to its evolution.

# %% [markdown]
# To download options data, you'll need to use the `Ticker.options` and `Ticker.option_chain` methods.

# %%
aapl = yf.Ticker('aapl')
aapl
# Out:
# 26   3.60  0.170000       5.105108   24387.0         23924           0.264412
# 27   1.67 -0.020000      -1.197604   78697.0         40383           0.219246
# 28   0.55 -0.130000     -19.402985  233135.0         31059           0.204598
# 29   0.14 -0.080000     -38.095238   92346.0         49913           0.207039
# 30   0.04 -0.030000     -42.857143   25306.0         22985           0.224617
# 31   0.01 -0.010000     -50.000000   19832.0         25932           0.242195
# 32   0.01 -0.010000     -50.000000    2826.0          9279           0.289070
# 33   0.01  0.000000       0.000000    1605.0         12591           0.343757
# 34   0.01  0.000000       0.000000     418.0         14500           0.390631
# 35   0.01  0.000000       0.000000      87.0          6207           0.437506
# 36   0.01  0.000000       0.000000       2.0          2157           0.484380
# 37   0.01  0.000000       0.000000     211.0         11998           0.500005
# 38   0.01  0.000000       0.000000       2.0          1555           0.546880
# 39   0.01  0.000000       0.000000       3.0          4568           0.593754
# 40   0.01  0.000000       0.000000       1.0          3209           0.656253
# 41   0.01  0.000000       0.000000      20.0          2063           0.750003
# 42   0.01  0.000000       0.000000      22.0          2168           0.812502
# 43   0.01  0.000000       0.000000       2.0          1273           0.906251
# 44   0.01  0.000000       0.000000       2.0          1991           0.968750
# 45   0.01  0.000000       0.000000      38.0           770           1.031255
# 46   0.01  0.000000       0.000000       1.0          1419           1.093755
# 47   0.01  0.000000       0.000000       2.0          1296           1.156254
# 48   0.01  0.000000       0.000000       3.0             9           1.250004
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# 5         True      REGULAR      USD
# 6         True      REGULAR      USD
# 7         True      REGULAR      USD
# 8         True      REGULAR      USD
# 9         True      REGULAR      USD
# 10        True      REGULAR      USD
# 11        True      REGULAR      USD
# 12        True      REGULAR      USD
# 13        True      REGULAR      USD
# 14        True      REGULAR      USD
# 15        True      REGULAR      USD
# 16        True      REGULAR      USD
# 17        True      REGULAR      USD
# 18        True      REGULAR      USD
# 19        True      REGULAR      USD
# 20        True      REGULAR      USD
# 21        True      REGULAR      USD
# 22        True      REGULAR      USD
# 23        True      REGULAR      USD
# 24        True      REGULAR      USD
# 25        True      REGULAR      USD
# 26        True      REGULAR      USD
# 27        True      REGULAR      USD
# 28       False      REGULAR      USD
# 29       False      REGULAR      USD
# 30       False      REGULAR      USD
# 31       False      REGULAR      USD
# 32       False      REGULAR      USD
# 33       False      REGULAR      USD
# 34       False      REGULAR      USD
# 35       False      REGULAR      USD
# 36       False      REGULAR      USD
# 37       False      REGULAR      USD
# 38       False      REGULAR      USD
# 39       False      REGULAR      USD
# 40       False      REGULAR      USD
# 41       False      REGULAR      USD
# 42       False      REGULAR      USD
# 43       False      REGULAR      USD
# 44       False      REGULAR      USD
# 45       False      REGULAR      USD
# 46       False      REGULAR      USD
# 47       False      REGULAR      USD
# 48       False      REGULAR      USD

# %%
type(options)
# Out:
# yfinance.ticker.Options

# %%
puts = options.puts
puts
# Out:
# 27   1.19 -0.470000     -28.313250  77724.0       11355.0           0.227059
# 28   2.66 -0.610000     -19.182394  16105.0       14461.0           0.230232
# 29   4.80 -0.400000      -7.766992   1063.0       10934.0           0.266121
# 30   7.20 -0.360000      -4.768214    306.0        2291.0           0.325202
# 31   9.70 -0.400000      -4.040400    276.0        3208.0           0.406256
# 32  12.20 -1.480001     -11.297713     22.0         120.0           0.483404
# 33  14.70 -0.450000      -2.999999     24.0         328.0           0.556645
# 34  17.20 -0.359999      -2.068958      1.0          35.0           0.626957
# 35  19.70 -1.860001      -9.144546      2.0          29.0           0.695316
# 36  22.15 -4.470001     -17.113327     25.0          11.0           0.726565
# 37  24.70 -0.510000      -2.031874      2.0          65.0           0.825197
# 38  27.20  0.000000       0.000000      2.0           1.0           0.887696
# 39  29.70  0.000000       0.000000      3.0           2.0           0.949219
# 40  34.95  0.000000       0.000000      3.0           0.0           0.671878
# 41  40.40  0.000000       0.000000     10.0           0.0           0.890626
# 42  45.00  0.000000       0.000000      NaN           0.0           1.496096
# 43  50.25 -3.940002      -7.400455      2.0           0.0           1.308597
# 44  64.70  0.000000       0.000000      NaN           NaN           1.550783
# 45  70.35  0.000000       0.000000      3.0           0.0           1.675783
# 46  74.45  0.000000       0.000000      NaN           1.0           0.000010
#
#     inTheMoney contractSize currency
# 0        False      REGULAR      USD
# 1        False      REGULAR      USD
# 2        False      REGULAR      USD
# 3        False      REGULAR      USD
# 4        False      REGULAR      USD
# 5        False      REGULAR      USD
# 6        False      REGULAR      USD
# 7        False      REGULAR      USD
# 8        False      REGULAR      USD
# 9        False      REGULAR      USD
# 10       False      REGULAR      USD
# 11       False      REGULAR      USD
# 12       False      REGULAR      USD
# 13       False      REGULAR      USD
# 14       False      REGULAR      USD
# 15       False      REGULAR      USD
# 16       False      REGULAR      USD
# 17       False      REGULAR      USD
# 18       False      REGULAR      USD
# 19       False      REGULAR      USD
# 20       False      REGULAR      USD
# 21       False      REGULAR      USD
# 22       False      REGULAR      USD
# 23       False      REGULAR      USD
# 24       False      REGULAR      USD
# 25       False      REGULAR      USD
# 26       False      REGULAR      USD
# 27       False      REGULAR      USD
# 28        True      REGULAR      USD
# 29        True      REGULAR      USD
# 30        True      REGULAR      USD
# 31        True      REGULAR      USD
# 32        True      REGULAR      USD
# 33        True      REGULAR      USD
# 34        True      REGULAR      USD
# 35        True      REGULAR      USD
# 36        True      REGULAR      USD
# 37        True      REGULAR      USD
# 38        True      REGULAR      USD
# 39        True      REGULAR      USD
# 40        True      REGULAR      USD
# 41        True      REGULAR      USD
# 42        True      REGULAR      USD
# 43        True      REGULAR      USD
# 44        True      REGULAR      USD
# 45        True      REGULAR      USD
# 46        True      REGULAR      USD

# %% [markdown]
# ## How to Get Institutional Holders Using yfinance

# %%
aapl.institutional_holders
# Out:
#                                 Holder      Shares Date Reported   % Out  \
# 0           Vanguard Group, Inc. (The)  1266332667    2021-09-29  0.0775
# 1                       Blackrock Inc.  1026223983    2021-09-29  0.0628
# 2              Berkshire Hathaway, Inc   887135554    2021-09-29  0.0543
# 3             State Street Corporation   622163541    2021-09-29  0.0381
# 4                             FMR, LLC   350617759    2021-09-29  0.0215
# 5        Geode Capital Management, LLC   259894947    2021-09-29  0.0159
# 6           Northern Trust Corporation   195321532    2021-09-29  0.0120
# 7        Price (T.Rowe) Associates Inc   188489966    2021-09-29  0.0115
# 8    Norges Bank Investment Management   167580974    2020-12-30  0.0103
# 9  Bank Of New York Mellon Corporation   149381117    2021-09-29  0.0091
#
#           Value
# 0  179186072380
# 1  145210693594
# 2  125529680891
# 3   88036141051
# 4   49612412898
# 5   36775135000
# 6   27637996778
# 7   26671330189
# 8   22236319440
# 9   21137428055

# %% [markdown]
# ## Why You Shouldn’t Use Yahoo Finance for Live Trading

# %%
fb = yf.Ticker('fb')
meta = yf.Ticker('meta')
fb.get_cashflow()
# Out:
#                                              2020-12-31    2019-12-31  \
# Investments                               -1.452000e+10 -4.254000e+09
# Change To Liabilities                      9.100000e+07  2.360000e+08
# Total Cashflows From Investing Activities -3.005900e+10 -1.986400e+10
# Net Borrowings                            -5.800000e+08 -7.750000e+08
# Total Cash From Financing Activities      -1.029200e+10 -7.299000e+09
# Change To Operating Activities            -1.302000e+09  8.975000e+09
# Net Income                                 2.914600e+10  1.848500e+10
# Change In Cash                            -1.325000e+09  9.155000e+09
# Repurchase Of Stock                       -9.836000e+09 -6.539000e+09
# Effect Of Exchange Rate                    2.790000e+08  4.000000e+06
# Total Cash From Operating Activities       3.874700e+10  3.631400e+10
# Depreciation                               6.862000e+09  5.741000e+09
# Other Cashflows From Investing Activities -3.600000e+07 -3.600000e+07
# Change To Account Receivables             -1.512000e+09 -1.961000e+09
# Other Cashflows From Financing Activities  1.240000e+08  1.500000e+07
# Change To Netincome                        5.462000e+09  4.838000e+09
# Capital Expenditures                      -1.511500e+10 -1.510200e+10
#
#                                              2018-12-31    2017-12-31
# Investments                                2.449000e+09 -1.325000e+10
# Change To Liabilities                      2.740000e+08  4.700000e+07
# Total Cashflows From Investing Activities -1.160300e+10 -2.011800e+10
# Net Borrowings                             5.000000e+08  5.000000e+08
# Total Cash From Financing Activities      -1.557200e+10 -5.235000e+09
# Change To Operating Activities             9.100000e+07  3.449000e+09
# Net Income                                 2.211200e+10  1.593400e+10
# Change In Cash                             1.920000e+09 -9.050000e+08
# Repurchase Of Stock                       -1.608700e+10 -5.222000e+09
# Effect Of Exchange Rate                   -1.790000e+08  2.320000e+08
# Total Cash From Operating Activities       2.927400e+10  2.421600e+10
# Depreciation                               4.315000e+09  3.025000e+09
# Other Cashflows From Investing Activities -3.600000e+07 -1.300000e+07
# Change To Account Receivables             -1.892000e+09 -1.609000e+09
# Other Cashflows From Financing Activities  1.500000e+07 -1.300000e+07
# Change To Netincome                        4.374000e+09  3.370000e+09
# Capital Expenditures                      -1.391500e+10 -6.733000e+09

# %%
meta.get_cashflow()
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []
